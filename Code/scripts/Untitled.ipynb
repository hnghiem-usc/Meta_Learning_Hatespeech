# %%
# !pwd
# Out:
# /Users/hn/Library/CloudStorage/GoogleDrive-hnghiem@usc.edu/My Drive/USC/ISI/Hate Sequel/Code/scripts

# %%
# !python run_test.py
# Out:
# /Users/hn/Library/CloudStorage/GoogleDrive-hnghiem@usc.edu/My Drive/USC/ISI/Hate Sequel/Code/scripts/../utils/loader.py:197: FutureWarning: load_metric is deprecated and will be removed in the next major version of datasets. Use 'evaluate.load' instead, from the new library 🤗 Evaluate: https://huggingface.co/docs/evaluate
#   metric = load_metric('accuracy')
# ------------------------------ SEED : 123 ------------------------------
# ---------------TRAINING FOR  K_val = 100 ---------------
# Training domains: ['trac' 'davidson' 'waseem' 'jigsaw' 'founta' 'gab_kennedy' 'goldbeck'
#  'hateval']
# Validation domains: ['olid'] (200, 4)
# Test domains: ['olid'] (300, 4)
# ...
